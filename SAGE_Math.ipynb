# %%
#Problem 13

# %%
x = var('x')

# %%
def f(x): return 2*x + x^2 - x^3

# %%
p = []

# %%
p.append(plot(f(x),(x,-1.5,-1), color='blue'))

# %%
p.append(plot(f(x),(x,-1,1), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,1,1.5), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, -1, 1)

# %%
int
# Out:
# 2/3

# %%
#Problem 69

# %%
x=var('x')

# %%
def f(x): return x*sqrt(4-x^2)

# %%
def g(x): return (-4*x)/(x^2+1)

# %%
p = []

# %%
p.append(plot(f(x),(x,0,2), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(g(x),(x,0,2), color='red', fill=true, legend_label='g(x)'))

# %%
p.append(line([(2,-3),(2,3)], color='green'))

# %%
sum(p)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
int = integral(f(x) - g(x), x, 0, 2)

# %%
int
# Out:
# 2*log(5) + 8/3

# %%
numerical_approx(int)
# Out:
# 5.88554249153487
